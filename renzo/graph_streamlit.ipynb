# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
speeches_df = pd.read_csv('../raw_data/speeches_with_paragraphs_processed.csv')

# %%
speeches_df
# Out:
#         Unnamed: 0  iso    year  \
# 0                0  BEL  1950.0
# 1                0  BEL  1950.0
# 2                0  BEL  1950.0
# 3                0  BEL  1950.0
# 4                0  BEL  1950.0
# ...            ...  ...     ...
# 117950       10397  HUN  2014.0
# 117951       10397  HUN  2014.0
# 117952       10397  HUN  2014.0
# 117953       10397  HUN  2014.0
# 117954       10397  HUN  2014.0
#
#                                                  speeches country_dup  \
# 0       Never before have men throughout the world mor...     Belgium
# 1       We have used these great, just and noble words...     Belgium
# 2       These are not, of course, the only lessons of ...     Belgium
# 3       From the first day, the general debate in the ...     Belgium
# 4       I had listened attentively to Mr. Vyshinsky’s ...     Belgium
# ...                                                   ...         ...
# 117950  Two years ago here in New York, Hurricane Sand...     Hungary
# 117951  Why can we not listen to the wisdom and advice...     Hungary
# 117952  I note, among others, the high incidence of de...     Hungary
# 117953  Only a few days ago, we read that the carbon d...     Hungary
# 117954  The New York example tells us that we are not ...     Hungary
#
#        Name of Person Speaking       Post    order  country  speech_length  \
# 0             Mr. VAN ZEELAND         NaN  10375.0  Belgium          18419
# 1             Mr. VAN ZEELAND         NaN  10375.0  Belgium          18419
# 2             Mr. VAN ZEELAND         NaN  10375.0  Belgium          18419
# 3             Mr. VAN ZEELAND         NaN  10375.0  Belgium          18419
# 4             Mr. VAN ZEELAND         NaN  10375.0  Belgium          18419
# ...                        ...        ...      ...      ...            ...
# 117950              János Áder  President   1631.0  Hungary           7812
# 117951              János Áder  President   1631.0  Hungary           7812
# 117952              János Áder  President   1631.0  Hungary           7812
# 117953              János Áder  President   1631.0  Hungary           7812
# 117954              János Áder  President   1631.0  Hungary           7812
#
#                                          cleaned_speeches  \
# 0       never before have men throughout the world mor...
# 1       we have used these great just and noble words ...
# 2       these are not of course the only lessons of th...
# 3       from the first day the general debate in the a...
# 4       i had listened attentively to mr vyshinsky’s s...
# ...                                                   ...
# 117950  two years ago here in new york hurricane sandy...
# 117951  why can we not listen to the wisdom and advice...
# 117952  i note among others the high incidence of derm...
# 117953  only a few days ago we read that the carbon di...
# 117954  the new york example tells us that we are not ...
#
#                                       preprocessed_speech  topic_num  \
# 0       never man throughout world fervently unanimous...          0
# 1       use great noble word much become wear eye lose...          3
# 2       course lesson korean affair would well weigh s...          3
# 3       first day general debate assembly justify high...          0
# 4       listen attentively mr vyshinsky ’s speech th m...          0
# ...                                                   ...        ...
# 117950  two year ago new york hurricane sandy cause da...          0
# 117951  listen wisdom advice scientist accept scientif...          1
# 117952  note among other high incidence dermatological...          1
# 117953  day ago read carbon dioxide concentration neve...          1
# 117954  new york example tell we twentyfourth hour twe...          8
#
#                       topic     score
# 0                   bla_bla  0.627509
# 1                       war  0.412248
# 2                       war  0.583786
# 3                   bla_bla  0.781970
# 4                   bla_bla  0.678787
# ...                     ...       ...
# 117950              bla_bla  0.418813
# 117951              climate  0.422659
# 117952              climate  0.532441
# 117953              climate  0.681089
# 117954  humanitarian crises  0.339883
#
# [117955 rows x 15 columns]

# %%
count_topics = speeches_df.groupby(['country','year','topic'])[['iso']].count()

# %%
options = list(set(speeches_df['topic']))
options
# Out:
# ['gender_issues',
#  'decolonization',
#  'war',
#  'drugs_crime',
#  'development',
#  'migration_refugees',
#  'data_stats',
#  'humanitarian crises',
#  'multilateralism',
#  'education_children',
#  'climate',
#  'human_rights',
#  'pandemic_health',
#  'disarmament',
#  'Political_polarization',
#  'terrorism',
#  'bla_bla']

# %%
df_ = count_topics.reset_index().rename({'iso':'count'}, axis=1)
df_['count'] = 1
war_df = df_.loc[df_.topic == variable]
war_df =war_df.groupby(['year'])[['topic']].count().reset_index().rename({'topic':'count'}, axis=1)


climate = df_.loc[df_.topic == 'climate']
climate = climate.groupby(['year'])[['topic']].count().reset_index().rename({'topic':'count'}, axis=1)

# %%
sns.lineplot(war_df,x='year', y='count')
sns.lineplot(climate,x='year', y='count');

# %%
df_.loc[(df_.country == 'Afghanistan') & (df_.year == 1952)]
# Out:
#        country    year    topic  count
# 0  Afghanistan  1952.0  bla_bla      3

# %%
df_
# Out:
#            country    year            topic  count
# 0      Afghanistan  1952.0          bla_bla      1
# 1      Afghanistan  1957.0          bla_bla      1
# 2      Afghanistan  1957.0              war      1
# 3      Afghanistan  1958.0          bla_bla      1
# 4      Afghanistan  1958.0      disarmament      1
# ...            ...     ...              ...    ...
# 44536     Zimbabwe  2020.0          bla_bla      1
# 44537     Zimbabwe  2020.0    gender_issues      1
# 44538     Zimbabwe  2021.0          bla_bla      1
# 44539     Zimbabwe  2021.0      development      1
# 44540     Zimbabwe  2021.0  pandemic_health      1
#
# [44541 rows x 4 columns]
