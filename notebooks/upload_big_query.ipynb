# %%
import pandas as pd
from google.cloud import bigquery

def load_data_to_bq(
        data: pd.DataFrame,
        gcp_project:str,
        bq_dataset:str,
        table: str,
        truncate: bool
    ) -> None:

    full_table_name = f"{gcp_project}.{bq_dataset}.{table}"
    client = bigquery.Client()

    # Define write mode and schema
    write_mode = "WRITE_TRUNCATE" if truncate else "WRITE_APPEND"
    job_config = bigquery.LoadJobConfig(write_disposition=write_mode)

    print(f"\n{'Write' if truncate else 'Append'} {full_table_name} ({data.shape[0]} rows)")

    # Load data
    job = client.load_table_from_dataframe(data, full_table_name, job_config=job_config)
    result = job.result()  # wait for the job to complete

    print(f"✅ Data saved to bigquery, with shape {data.shape}")

# %%
local_file = pd.read_csv('/home/ricorenzo/code/renzorico/raw_data_project/data_st.csv')
# local_file = local_file.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
local_file
# Out:
#         iso  year                                           speeches  country  \
# 0       BEL  1950  Never before have men throughout the world mor...  Belgium
# 1       BEL  1950  We have used these great, just and noble words...  Belgium
# 2       BEL  1950  These are not, of course, the only lessons of ...  Belgium
# 3       BEL  1950  From the first day, the general debate in the ...  Belgium
# 4       BEL  1950  I had listened attentively to Mr. Vyshinsky’s ...  Belgium
# ...     ...   ...                                                ...      ...
# 117491  HUN  2014  Two years ago here in New York, Hurricane Sand...  Hungary
# 117492  HUN  2014  Why can we not listen to the wisdom and advice...  Hungary
# 117493  HUN  2014  I note, among others, the high incidence of de...  Hungary
# 117494  HUN  2014  Only a few days ago, we read that the carbon d...  Hungary
# 117495  HUN  2014  The New York example tells us that we are not ...  Hungary
#
#                                          cleaned_speeches  \
# 0       never before have men throughout the world mor...
# 1       we have used these great just and noble words ...
# 2       these are not of course the only lessons of th...
# 3       from the first day the general debate in the a...
# 4       i had listened attentively to mr vyshinsky’s s...
# ...                                                   ...
# 117491  two years ago here in new york hurricane sandy...
# 117492  why can we not listen to the wisdom and advice...
# 117493  i note among others the high incidence of derm...
# 117494  only a few days ago we read that the carbon di...
# 117495  the new york example tells us that we are not ...
#
#                                       preprocessed_speech  topic_num  \
# 0       never man throughout world fervently unanimous...          3
# 1       use great noble word much become wear eye lose...          3
# 2       course lesson korean affair would well weigh s...          3
# 3       first day general debate assembly justify high...         14
# 4       listen attentively mr vyshinsky ’s speech th m...         14
# ...                                                   ...        ...
# 117491  two year ago new york hurricane sandy cause da...          1
# 117492  listen wisdom advice scientist accept scientif...          1
# 117493  note among other high incidence dermatological...          1
# 117494  day ago read carbon dioxide concentration neve...          1
# 117495  new york example tell we twentyfourth hour twe...          3
#
#                   topic                                  countries_recoded  \
# 0                   war                        ['South Korea', 'New York']
# 1                   war                                                 []
# 2                   war                                          ['Korea']
# 3       multilateralism  ['Netherlands', 'Chile', 'United States', 'USS...
# 4       multilateralism                               ['the Soviet Union']
# ...                 ...                                                ...
# 117491          climate  ['New York', 'New York City', 'New York', 'New...
# 117492          climate                                                 []
# 117493          climate  ['Montreal', 'United States', 'Paris', 'Montre...
# 117494          climate                                  ['New York City']
# 117495              war                                       ['New York']
#
#                                               top_5_words  bert_topic  \
# 0       ['four year' 'south korea' 'month ago' 'upon w...          -1
# 1       ['charter united' 'charter united nations' 'he...           5
# 2       ['government consider' 'zone peace' 'united na...           8
# 3       ['soviet union' 'general debate' 'delegation w...          -1
# 4       ['cooperation among nation' 'problem united' '...           1
# ...                                                   ...         ...
# 117491  ['despite fact' 'among other' 'ensure success'...          -1
# 117492  ['government people republic' 'government repu...          -1
# 117493  ['next year' 'become increasingly' 'last week'...          -1
# 117494  ['gross domestic product' 'hundred million' 't...           6
# 117495  ['government republic' 'government consider' '...          -1
#
#         bert_prob                                    ber_topic_words decade  \
# 0         0.00000  ['united', 'nations', 'united nations', 'inter...  1950s
# 1         1.00000  ['world', 'peace', 'war', 'we', 'man', 'people...  1950s
# 2         0.59265  ['korea', 'korean', 'republic korea', 'peninsu...  1950s
# 3         0.00000  ['united', 'nations', 'united nations', 'inter...  1950s
# 4         1.00000  ['nuclear', 'disarmament', 'weapon', 'nuclear ...  1950s
# ...           ...                                                ...    ...
# 117491    0.00000  ['united', 'nations', 'united nations', 'inter...  2010s
# 117492    0.00000  ['united', 'nations', 'united nations', 'inter...  2010s
# 117493    0.00000  ['united', 'nations', 'united nations', 'inter...  2010s
# 117494    1.00000  ['climate', 'climate change', 'change', 'islan...  2010s
# 117495    0.00000  ['united', 'nations', 'united nations', 'inter...  2010s
#
#         year_range continent
# 0        1946-1970    Europe
# 1        1946-1970    Europe
# 2        1946-1970    Europe
# 3        1946-1970    Europe
# 4        1946-1970    Europe
# ...            ...       ...
# 117491  1990-today    Europe
# 117492  1990-today    Europe
# 117493  1990-today    Europe
# 117494  1990-today    Europe
# 117495  1990-today    Europe
#
# [117496 rows x 16 columns]

# %%
local_file.dropna(subset=['country', 'speeches'], axis=0, inplace=True)

# %%
local_file['year'] = local_file['year'].astype(int)

# %%
local_file.head()
# Out:
#    iso  year                                           speeches  country  \
# 0  BEL  1950  Never before have men throughout the world mor...  Belgium
# 1  BEL  1950  We have used these great, just and noble words...  Belgium
# 2  BEL  1950  These are not, of course, the only lessons of ...  Belgium
# 3  BEL  1950  From the first day, the general debate in the ...  Belgium
# 4  BEL  1950  I had listened attentively to Mr. Vyshinsky’s ...  Belgium
#
#                                     cleaned_speeches  \
# 0  never before have men throughout the world mor...
# 1  we have used these great just and noble words ...
# 2  these are not of course the only lessons of th...
# 3  from the first day the general debate in the a...
# 4  i had listened attentively to mr vyshinsky’s s...
#
#                                  preprocessed_speech  topic_num  \
# 0  never man throughout world fervently unanimous...          3
# 1  use great noble word much become wear eye lose...          3
# 2  course lesson korean affair would well weigh s...          3
# 3  first day general debate assembly justify high...         14
# 4  listen attentively mr vyshinsky ’s speech th m...         14
#
#              topic                                  countries_recoded  \
# 0              war                        ['South Korea', 'New York']
# 1              war                                                 []
# 2              war                                          ['Korea']
# 3  multilateralism  ['Netherlands', 'Chile', 'United States', 'USS...
# 4  multilateralism                               ['the Soviet Union']
#
#                                          top_5_words  bert_topic  bert_prob  \
# 0  ['four year' 'south korea' 'month ago' 'upon w...          -1    0.00000
# 1  ['charter united' 'charter united nations' 'he...           5    1.00000
# 2  ['government consider' 'zone peace' 'united na...           8    0.59265
# 3  ['soviet union' 'general debate' 'delegation w...          -1    0.00000
# 4  ['cooperation among nation' 'problem united' '...           1    1.00000
#
#                                      ber_topic_words decade year_range  \
# 0  ['united', 'nations', 'united nations', 'inter...  1950s  1946-1970
# 1  ['world', 'peace', 'war', 'we', 'man', 'people...  1950s  1946-1970
# 2  ['korea', 'korean', 'republic korea', 'peninsu...  1950s  1946-1970
# 3  ['united', 'nations', 'united nations', 'inter...  1950s  1946-1970
# 4  ['nuclear', 'disarmament', 'weapon', 'nuclear ...  1950s  1946-1970
#
#   continent
# 0    Europe
# 1    Europe
# 2    Europe
# 3    Europe
# 4    Europe

# %%
eval('2 + 2')
# Out:
# 4

# %%
import ast
local_file['countries_recoded'] = local_file['countries_recoded'].apply(ast.literal_eval)

# %%
load_data_to_bq(local_file, 'lewagon-bootcamp-384011' ,'production_dataset','speeches', True)
# Out:
# Write lewagon-bootcamp-384011.production_dataset.speeches (117496 rows)
# ✅ Data saved to bigquery, with shape (117496, 16)

# %%
local_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117496 entries, 0 to 117495
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   iso                  117496 non-null  object
#  1   year                 117496 non-null  int64
#  2   speeches             117496 non-null  object
#  3   country              117496 non-null  object
#  4   cleaned_speeches     117496 non-null  object
#  5   preprocessed_speech  117496 non-null  object
#  6   topic_num            117496 non-null  int64
#  7   topic                117496 non-null  object
#  8   countries_recoded    117496 non-null  object
#  9   top_5_words          117496 non-null  object
#  10  bert_topic           117496 non-null  int64
#  11  bert_prob            117496 non-null  float64
#  12  ber_topic_words      117496 non-null  object
#  13  decade               117496 non-null  object
#  14  year_range           117496 non-null  object
#  15  continent            117496 non-null  object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 14.3+ MB
